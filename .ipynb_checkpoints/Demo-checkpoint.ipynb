# %% [markdown]
# # Demonstration for the automatic PKIKP onset picker

# %% [markdown]
# ## Model training

# %%
from Trainer import *

# %% [markdown]
# ### Training datasets

# %% [markdown]
# First, load the training dataset of synthetic waveforms, which has three subsets: regular (synthetic P waves), target (particular emergent P waves), and control set (real noise). Each set contains ~ 100,000 samples. The waveforms are sampled at 40 Hz and generated to 20-s long.

# %%
## basic parameters
sampling_rate = 40
waveform_len = 20
loaded_num = 100000

## Load waveforms and onset labels. 
## The labels are float indicating p onset locations for synthetic p waves,
## and 0 for noise.
folder = "Training_data"
subset_names = ["RegularP","TargetP","Noise"]

x = []
y = []
for file in subset_names:
    file_addr = os.path.join(folder,file+".hdf5")
    waves, onsets = load_training_data(file_addr, loaded_num)
    x.append(waves)
    y.append(onsets)
print("Number in total: %d"%sum([len(a) for a in x]))
# Out:
# Loading a dataset: Training_data/RegularP.hdf5
# Loaded number: 98423
# Loading a dataset: Training_data/TargetP.hdf5
# Loaded number: 98440
# Loading a dataset: Training_data/Noise.hdf5
# Loaded number: 98412
# Number in total: 295275

# %%
# Plot an example from each subset
fig,ax = plt.subplots(nrows = 3, sharex = True)
for i in range(3):
    ax[i].plot(x[i][0],label = subset_names[i])
    ax[i].axvline(y[i][0]*sampling_rate,c = "r",label = "True label")
    ax[i].set_ylabel("Amplitude", fontsize = 15)
    ax[i].set_yticks([-1,0,1])
    ax[i].legend(loc = "upper left")
ax[-1].set_xlabel("Time (s)", fontsize = 15)
ax[-1].set_xticks(np.arange(0,801,100),np.arange(0,21,2.5))
plt.show()

# %% [markdown]
# ### Training

# %% [markdown]
# Build the network using TensorFlow.

# %%
model_raw = CNN_picker(npts = waveform_len*sampling_rate)
model_raw.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 800, 1)]          0
#
#  conv1d (Conv1D)             (None, 800, 32)           256
#
#  max_pooling1d (MaxPooling1  (None, 400, 32)           0
#  D)
#
#  batch_normalization (Batch  (None, 400, 32)           128
#  Normalization)
#
#  conv1d_1 (Conv1D)           (None, 400, 64)           10304
#
#  max_pooling1d_1 (MaxPoolin  (None, 200, 64)           0
#  g1D)
#
#  batch_normalization_1 (Bat  (None, 200, 64)           256
#  chNormalization)
#
#  conv1d_2 (Conv1D)           (None, 200, 128)          32896
#
#  max_pooling1d_2 (MaxPoolin  (None, 100, 128)          0
#  g1D)
#
#  batch_normalization_2 (Bat  (None, 100, 128)          512
#  chNormalization)
#
#  conv1d_3 (Conv1D)           (None, 100, 256)          98560
#
#  max_pooling1d_3 (MaxPoolin  (None, 50, 256)           0
#  g1D)
#
#  batch_normalization_3 (Bat  (None, 50, 256)           1024
#  chNormalization)
#
#  flatten (Flatten)           (None, 12800)             0
#
#  dense (Dense)               (None, 200)               2560200
#
#  batch_normalization_4 (Bat  (None, 200)               800
#  chNormalization)
#
#  dense_1 (Dense)             (None, 200)               40200
#
#  batch_normalization_5 (Bat  (None, 200)               800
#  chNormalization)
#
#  dense_2 (Dense)             (None, 1)                 201
#
# =================================================================
# Total params: 2746137 (10.48 MB)
# Trainable params: 2744377 (10.47 MB)
# Non-trainable params: 1760 (6.88 KB)
# _________________________________________________________________

# %% [markdown]
# Train the model and plot the curves of loss during the training process. An early stopping method that allows training stops early if the validation loss has no longer decreased over 5 epochs is used. A warm-up period of 10 epochs is set for early stopping.

# %%
# Train
x = np.vstack(x)
y = np.vstack(y)

trainer(x, y, 
        model_raw, 
        epochs = 20, 
        validation_split = 0.2, 
        batch_size = 32, 
        early_stop = True, 
        verbose_training = 1, 
        shuffle = True, # Shuffle training data before each epoch
        plot_hist = True, save_plot = "Loss_curve.jpg"
       )
# Out:
# Epoch 1/20
# 7382/7382 [==============================] - 270s 36ms/step - loss: 0.5248 - val_loss: 0.3205
# Epoch 2/20
# 7382/7382 [==============================] - 295s 40ms/step - loss: 0.3827 - val_loss: 0.1336
# Epoch 3/20
# 7382/7382 [==============================] - 286s 39ms/step - loss: 0.3735 - val_loss: 0.1148
# Epoch 4/20
# 7382/7382 [==============================] - 302s 41ms/step - loss: 0.3652 - val_loss: 0.1374
# Epoch 5/20
# 7382/7382 [==============================] - 290s 39ms/step - loss: 0.3583 - val_loss: 0.2844
# Epoch 6/20
# 7382/7382 [==============================] - 286s 39ms/step - loss: 0.3525 - val_loss: 0.1394
# Epoch 7/20
# 7382/7382 [==============================] - 289s 39ms/step - loss: 0.3501 - val_loss: 0.2208
# Epoch 8/20
# 7382/7382 [==============================] - 279s 38ms/step - loss: 0.3410 - val_loss: 0.1119
# Epoch 9/20
# 7382/7382 [==============================] - 274s 37ms/step - loss: 0.3354 - val_loss: 0.0875
# Epoch 10/20
# 7382/7382 [==============================] - 280s 38ms/step - loss: 0.3285 - val_loss: 0.1365
# Epoch 11/20
# 7382/7382 [==============================] - 282s 38ms/step - loss: 0.3343 - val_loss: 0.1003
# Epoch 12/20
# 7382/7382 [==============================] - 278s 38ms/step - loss: 0.3316 - val_loss: 0.0768
# Epoch 13/20
# 7382/7382 [==============================] - 277s 37ms/step - loss: 0.3295 - val_loss: 0.1482
# Epoch 14/20
# 7382/7382 [==============================] - 276s 37ms/step - loss: 0.3196 - val_loss: 0.0909
# Epoch 15/20
# 7382/7382 [==============================] - 279s 38ms/step - loss: 0.3348 - val_loss: 0.1311
# Epoch 16/20
# 7382/7382 [==============================] - 283s 38ms/step - loss: 0.3240 - val_loss: 0.1915
# Epoch 17/20
# 7381/7382 [============================>.] - ETA: 0s - loss: 0.3227Restoring model weights from the end of the best epoch: 12.
# 7382/7382 [==============================] - 276s 37ms/step - loss: 0.3227 - val_loss: 0.1476
# Epoch 17: early stopping
# Training starts at 2025-03-12T02:18:00.273173Z ; costing: 4803.344533920288

# %% [markdown]
# ## Onset picking test

# %%
from Picker import *

# %% [markdown]
# ### Picking

# %% [markdown]
# Here we load the trained model.

# %%
model = load_model("Trained_model.keras")

# %% [markdown]
# Read an observed real PKIKP waveform example. Here, the waveform has 150-s length. The predicted PKIKP onset by ak135 model (Kennett et al., 1995) is located at the 60th second. Hand-picked PKIKP absolute travel time is provided in its information.

# %%
tr = read("Test_PKIKP/PKP_NE22.YP.BHZ.SAC")
PKIKP_travel_time = tr[0].stats.sac.t2
waveform_start = tr[0].stats.sac.b
onset = PKIKP_travel_time - waveform_start
prediction = 60 

print("Wavefrom shape:",np.shape(tr))
print("PKIKP onset: ak135 prediction: %.2f s; Hand picking: %.2f s"%(prediction,onset))
# Out:
# Wavefrom shape: (1, 6001)
# PKIKP onset: ak135 prediction: 60.00 s; Hand picking: 56.90 s

# %% [markdown]
# Pre-process the waveform. A default 50-s length waveform segment around the ak135 prediction is cut as the input of the automatic picker.

# %%
sampling_rate = 40
len_input = 50
freq_filter = [0.5,2]
tr_cut = pre_process(tr, sampling_rate, len_input, freq_filter[0], freq_filter[1])

# %% [markdown]
# Pick the PKIKP onset on the processed waveform by calling the Picker function. A 20-s length window is shifting along the input waveform, and the network model returns an instantaneous pick for each step. The pick with the highest quality is chosen as the optimal one.

# %%
auto_pick, quality = picker(tr_cut,model, sampling_rate, return_optimal = True)

print("Auto picked PKIKP onset: %.2f s picking quality: %.2f"%(auto_pick[0], quality[0]))
onset_in_window = onset - prediction + len_input / 2
print("Manual pick on the waveform: %.2f s"%onset_in_window)
# Out:
# Auto picked PKIKP onset: 21.66 s picking quality: 0.59
# Manual pick on the waveform: 21.90 s

# %% [markdown]
# We can simply execute the Picker.py file to do the job above.

# %%
# !python Picker.py --data_list Test_PKIKP/List.txt --save_pick Test_PKIKP/Picks.txt --save_plot Test_PKIKP
# Out:
# Test_PKIKP/PKP_320.Z8.BHZ.SAC
#  Auto picked PKIKP onset: 24.66 s; Picking quality: 0.54
# ---------------
# Test_PKIKP/PKP_DLV.RM.BHZ.SAC
#  Auto picked PKIKP onset: 26.79 s; Picking quality: 0.51
# ---------------
# Test_PKIKP/PKP_NE22.YP.BHZ.SAC
#  Auto picked PKIKP onset: 21.66 s; Picking quality: 0.59
# ---------------

# %% [markdown]
# ### Result plotting

# %% [markdown]
# We can acquire all picks with quality and get a quality plot.

# %%
auto_pick_plot(tr_cut, model, "Test_PKIKP/PKP_NE22.YP.BHZ.SAC.jpg")

# %% [markdown]
# An animation displaying the dynamic picking process is saved.

# %%
picking_animation(tr_cut, model, save_name = "Test_PKIKP/Animation.mp4")
